# %%
import pandas as pd
data = pd.read_csv('../data/CDI web content.csv', sep=",")
data.head()
# Out:
#   crm_CDI_WebContent_Campaign crm_CDI_WebContent_Campaign_Name
# 0                         NaN                              NaN  \
# 1                         NaN                              NaN
# 2                         NaN                              NaN
# 3                         NaN                              NaN
# 4                         NaN                              NaN
#
#                              crm_CDI_WebContent_Name
# 0  [CLONE]: [CLONE]: LI - enquête KamerAcademie L...  \
# 1  [CLONE]: [CLONE]: LI - enquête KamerAcademie L...
# 2        [CLONE]: LI - enquête duurzame initiatieven
# 3  [CLONE]: LI - enquête KamerAcademie Limburg - ...
# 4  [CLONE]: LI - enquête KamerAcademie Limburg (D...
#
#          crm_CDI_WebContent_Web_Content crm_CDI_WebContent_Gemaakt_door_Naam_
# 0  841F9ABF-88F9-EA11-8115-001DD8B72B62                        Richard, Laura  \
# 1  E4FF6FC8-EA11-EB11-8114-001DD8B72B61                    Olyslaegers, Sofie
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4073 entries, 0 to 4072
# Data columns (total 11 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   crm_CDI_WebContent_Campaign                        3830 non-null   object
#  1   crm_CDI_WebContent_Campaign_Name                   3830 non-null   object
#  2   crm_CDI_WebContent_Name                            4073 non-null   object
#  3   crm_CDI_WebContent_Web_Content                     4073 non-null   object
#  4   crm_CDI_WebContent_Gemaakt_door_Naam_              4073 non-null   object
#  5   crm_CDI_WebContent_Created_On                      4073 non-null   object
#  6   crm_CDI_WebContent_Gewijzigd_door_Naam_            4073 non-null   object
#  7   crm_CDI_WebContent_Modified_On                     4073 non-null   object
# ...

# %%
data.isnull().sum()
# Out:
# crm_CDI_WebContent_Campaign                          243
# crm_CDI_WebContent_Campaign_Name                     243
# crm_CDI_WebContent_Name                                0
# crm_CDI_WebContent_Web_Content                         0
# crm_CDI_WebContent_Gemaakt_door_Naam_                  0
# crm_CDI_WebContent_Created_On                          0
# crm_CDI_WebContent_Gewijzigd_door_Naam_                0
# crm_CDI_WebContent_Modified_On                         0
# crm_CDI_WebContent_Owner                               0
# crm_CDI_WebContent_Owner_Name                          0
# crm_CDI_WebContent_Het_bezitten_van_Business_Unit      0
# dtype: int64
