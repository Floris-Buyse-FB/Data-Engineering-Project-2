# %%
import pandas as pd
data = pd.read_csv('../data/Afspraak betreft account_cleaned.csv', sep=",")
data.head()

data['crm_Afspraak_BETREFT_ACCOUNT_KeyPhrases'] = data['crm_Afspraak_BETREFT_ACCOUNT_KeyPhrases'].replace('\[NAME\] ,*','', regex=True)
# Out:
#   crm_Afspraak_BETREFT_ACCOUNT_Afspraak crm_Afspraak_BETREFT_ACCOUNT_Thema  \
# 0  00082DAA-24BF-ED11-83FF-6045BD8952CE                       Lidmaatschap
# 1  00082DAA-24BF-ED11-83FF-6045BD8952CE                       Lidmaatschap
# 2  00109C77-4D09-EB11-8114-001DD8B72B61                       Lidmaatschap
# 3  0011A5D9-CC9A-EC11-B400-0022488005A7                         Financieel
# 4  0016532E-14E3-EC11-BB3C-000D3ABCA38B                       Lidmaatschap
#
#   crm_Afspraak_BETREFT_ACCOUNT_Subthema  \
# 0               Retentie (Lidmaatschap)
# 1               Retentie (Lidmaatschap)
# 2               Retentie (Lidmaatschap)
# 3                          Financiering
# 4               Retentie (Lidmaatschap)
#
#   crm_Afspraak_BETREFT_ACCOUNT_Onderwerp  \
# 0                    ov-ledenbezoek-2023
# 1                    ov-ledenbezoek-2023
# 2                    ov-ledenbezoek-2020
# 3         OV-Kennismaking inzake funding
# 4                    ov-ledenbezoek-2022
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8595 entries, 0 to 8594
# Data columns (total 7 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   crm_Afspraak_BETREFT_ACCOUNT_Afspraak    8595 non-null   object
#  1   crm_Afspraak_BETREFT_ACCOUNT_Thema       8592 non-null   object
#  2   crm_Afspraak_BETREFT_ACCOUNT_Subthema    8592 non-null   object
#  3   crm_Afspraak_BETREFT_ACCOUNT_Onderwerp   8559 non-null   object
#  4   crm_Afspraak_BETREFT_ACCOUNT_Betreft_id  8595 non-null   object
#  5   crm_Afspraak_BETREFT_ACCOUNT_Eindtijd    8595 non-null   object
#  6   crm_Afspraak_BETREFT_ACCOUNT_KeyPhrases  7827 non-null   object
# dtypes: object(7)
# memory usage: 470.2+ KB

# %%
data['crm_Afspraak_BETREFT_ACCOUNT_KeyPhrases']
# Out:
# 0        grootste visverwerkende  veel administratieve...
# 1        grootste visverwerkende  veel administratieve...
# 2       china en india , india en china , verschillend...
# 3       interesse , ervaringen , ondernemers , investe...
# 4       verwerkende fabriek , nodeloze oproepingen , g...
#                               ...
# 8590     huidige economische context , belangrijkste i...
# 8591    verschillende industrieën , belgië en luxembur...
# 8592    r&d manager , maleisie en turkije , data archi...
# 8593    industriële steigerbouw , eigen aandeel , posi...
# 8594     belangrijkste items , heidi mussche , winkels...
# Name: crm_Afspraak_BETREFT_ACCOUNT_KeyPhrases, Length: 8595, dtype: object

# %%
data['crm_Afspraak_BETREFT_ACCOUNT_KeyPhrases'] = data['crm_Afspraak_BETREFT_ACCOUNT_KeyPhrases'].replace('\[NAME\] ,*','', regex=True)

# %%
data.head()
# Out:
#   crm_Afspraak_BETREFT_ACCOUNT_Afspraak crm_Afspraak_BETREFT_ACCOUNT_Thema  \
# 0  00082DAA-24BF-ED11-83FF-6045BD8952CE                       Lidmaatschap
# 1  00082DAA-24BF-ED11-83FF-6045BD8952CE                       Lidmaatschap
# 2  00109C77-4D09-EB11-8114-001DD8B72B61                       Lidmaatschap
# 3  0011A5D9-CC9A-EC11-B400-0022488005A7                         Financieel
# 4  0016532E-14E3-EC11-BB3C-000D3ABCA38B                       Lidmaatschap
#
#   crm_Afspraak_BETREFT_ACCOUNT_Subthema  \
# 0               Retentie (Lidmaatschap)
# 1               Retentie (Lidmaatschap)
# 2               Retentie (Lidmaatschap)
# 3                          Financiering
# 4               Retentie (Lidmaatschap)
#
#   crm_Afspraak_BETREFT_ACCOUNT_Onderwerp  \
# 0                    ov-ledenbezoek-2023
# 1                    ov-ledenbezoek-2023
# 2                    ov-ledenbezoek-2020
# 3         OV-Kennismaking inzake funding
# 4                    ov-ledenbezoek-2022
#
# ...
