# %%
import pandas as pd
data = pd.read_csv('../data/persoon.csv', sep=",")

data.head()
# Out:
#                     crm_Persoon_persoon  crm_Persoon_Persoonsnr_  \
# 0  000025F6-EF15-EE11-8F6D-6045BD895420                   596398
# 1  00004BCD-BD69-E111-B43A-00505680000A                   320520
# 2  00005D29-3224-E311-8A47-005056B06EC4                   378241
# 3  00006033-9469-E111-B43A-00505680000A                   343308
# 4  0000628D-6169-E111-B43A-00505680000A                   325745
#
#   crm_Persoon_Reden_van_status crm_Persoon_Web_Login  \
# 0                       Actief                   NaN
# 1                     Inactief                   NaN
# 2                     Inactief                   NaN
# 3                       Actief                   NaN
# 4                       Actief                   NaN
#
#   crm_Persoon_Mail_regio_Antwerpen_Waasland  \
# 0                                       Nee
# 1                                       Nee
# 2                                       Nee
# 3                                       Nee
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 580981 entries, 0 to 580980
# Data columns (total 29 columns):
#  #   Column                                                     Non-Null Count   Dtype
# ---  ------                                                     --------------   -----
#  0   crm_Persoon_persoon                                        580981 non-null  object
#  1   crm_Persoon_Persoonsnr_                                    580981 non-null  int64
#  2   crm_Persoon_Reden_van_status                               580981 non-null  object
#  3   crm_Persoon_Web_Login                                      33821 non-null   object
#  4   crm_Persoon_Mail_regio_Antwerpen_Waasland                  580981 non-null  object
#  5   crm_Persoon_Mail_regio_Brussel_Hoofdstedelijk_Gewest       580981 non-null  object
#  6   crm_Persoon_Mail_regio_Limburg                             580981 non-null  object
# ...

# %%
data.replace('Nee', 0, inplace=True)
data.replace('Ja', 1, inplace=True)

# %%
data.head()
# Out:
#                     crm_Persoon_persoon  crm_Persoon_Persoonsnr_  \
# 0  000025F6-EF15-EE11-8F6D-6045BD895420                   596398
# 1  00004BCD-BD69-E111-B43A-00505680000A                   320520
# 2  00005D29-3224-E311-8A47-005056B06EC4                   378241
# 3  00006033-9469-E111-B43A-00505680000A                   343308
# 4  0000628D-6169-E111-B43A-00505680000A                   325745
#
#   crm_Persoon_Reden_van_status crm_Persoon_Web_Login  \
# 0                       Actief                   NaN
# 1                     Inactief                   NaN
# 2                     Inactief                   NaN
# 3                       Actief                   NaN
# 4                       Actief                   NaN
#
#    crm_Persoon_Mail_regio_Antwerpen_Waasland  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 580981 entries, 0 to 580980
# Data columns (total 29 columns):
#  #   Column                                                     Non-Null Count   Dtype
# ---  ------                                                     --------------   -----
#  0   crm_Persoon_persoon                                        580981 non-null  object
#  1   crm_Persoon_Persoonsnr_                                    580981 non-null  int64
#  2   crm_Persoon_Reden_van_status                               580981 non-null  object
#  3   crm_Persoon_Web_Login                                      33821 non-null   object
#  4   crm_Persoon_Mail_regio_Antwerpen_Waasland                  580981 non-null  int64
#  5   crm_Persoon_Mail_regio_Brussel_Hoofdstedelijk_Gewest       580981 non-null  int64
#  6   crm_Persoon_Mail_regio_Limburg                             580981 non-null  int64
# ...
