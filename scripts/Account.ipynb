# %%
import pandas as pd
data = pd.read_csv('../data/Account.csv', sep=",")
data.head()
# Out:
#                     crm_Account_Account crm_Account_Adres_Geografische_regio
# 0  00002561-6762-EC11-8F8F-000D3A2E7738                      Mechelen-Kempen  \
# 1  00002DAC-0A69-E111-B43A-00505680000A                      Oost-Vlaanderen
# 2  00002F96-DC68-E111-B43A-00505680000A                              Limburg
# 3  00005967-2959-E411-8F25-005056B06EB4                       Vlaams-Brabant
# 4  00006DCD-DF68-E111-B43A-00505680000A                      West-Vlaanderen
#
#   crm_Account_Adres_Geografische_subregio crm_Account_Adres_Plaats
# 0                             Kempen-West                Herentals  \
# 1                              Oudenaarde                   BEVERE
# 2                            Oost Limburg                  KINROOI
# 3                         Regio West Side                    HALLE
# 4                         Roeselare/Tielt                  EMELGEM
#
#   crm_Account_Adres_Postcode crm_Account_Adres_Provincie
# ...

# %%
data.reset_index(inplace=True)
data['index'] = data['index'] + 1

# %%
data.head()
# Out:
#    index                   crm_Account_Account
# 0      1  00002561-6762-EC11-8F8F-000D3A2E7738  \
# 1      2  00002DAC-0A69-E111-B43A-00505680000A
# 2      3  00002F96-DC68-E111-B43A-00505680000A
# 3      4  00005967-2959-E411-8F25-005056B06EB4
# 4      5  00006DCD-DF68-E111-B43A-00505680000A
#
#   crm_Account_Adres_Geografische_regio
# 0                      Mechelen-Kempen  \
# 1                      Oost-Vlaanderen
# 2                              Limburg
# 3                       Vlaams-Brabant
# 4                      West-Vlaanderen
#
#   crm_Account_Adres_Geografische_subregio crm_Account_Adres_Plaats
# 0                             Kempen-West                Herentals  \
# 1                              Oudenaarde                   BEVERE
# 2                            Oost Limburg                  KINROOI
# 3                         Regio West Side                    HALLE
# 4                         Roeselare/Tielt                  EMELGEM
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289054 entries, 0 to 289053
# Data columns (total 18 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   index                                    289054 non-null  int64
#  1   crm_Account_Account                      289054 non-null  object
#  2   crm_Account_Adres_Geografische_regio     279207 non-null  object
#  3   crm_Account_Adres_Geografische_subregio  275891 non-null  object
#  4   crm_Account_Adres_Plaats                 285266 non-null  object
#  5   crm_Account_Adres_Postcode               285136 non-null  object
#  6   crm_Account_Adres_Provincie              275931 non-null  object
#  7   crm_Account_Industriezone_Naam_          32929 non-null   object
#  8   crm_Account_Is_Voka_entiteit             289054 non-null  object
#  9   crm_Account_Ondernemingsaard             56712 non-null   object
# ...
