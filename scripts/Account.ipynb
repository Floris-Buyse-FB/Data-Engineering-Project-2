# %%
import pandas as pd
data = pd.read_csv('../data/Campagne.csv', sep=",")
data.head()
# Out:
#                   crm_Campagne_Campagne crm_Campagne_Campagne_Nr
# 0  002B50B9-36D9-E911-8105-001DD8B72B61            19-OV-01-0197  \
# 1  03418937-184E-ED11-BBA2-6045BD8952CE            22-OV-01-0172
# 2  037E70BA-6D2F-E911-80FB-001DD8B72B62            19-OV-01-0047
# 3  042E13FF-D097-ED11-AAD1-6045BD895B5A            23-OV-01-0043
# 4  05FB51E2-7564-EB11-811B-001DD8B72B62            21-OV-01-0020
#
#   crm_Campagne_Einddatum                                  crm_Campagne_Naam
# 0     16-9-2019 15:00:00  OV-NW-Voka Update-AIO-Sep2019-Een nieuw vennoo...  \
# 1     10-2-2023 14:30:00   OV-MA/NW-Regiolunch-Zaken die smaken-Meetjesland
# 2     27-3-2019 15:00:00    OV-Match-Lunchmeeting Sofie Bracke - Maart 2019
# 3      6-2-2023 10:00:00  OV-NW-AIO-EDIH-DIGITALIS-Voka Update-Big Refre...
# 4     11-2-2021 12:30:00  OV-NW-AIO-Voka Update-Big Refresh-Voorjaar 202...
#
#                           crm_Campagne_Naam_in_email
# 0  OV-NW-Voka Update-AIO-Sep2019-Een nieuw vennoo...  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   crm_Campagne_Campagne          168 non-null    object
#  1   crm_Campagne_Campagne_Nr       168 non-null    object
#  2   crm_Campagne_Einddatum         168 non-null    object
#  3   crm_Campagne_Naam              168 non-null    object
#  4   crm_Campagne_Naam_in_email     168 non-null    object
#  5   crm_Campagne_Reden_van_status  168 non-null    object
#  6   crm_Campagne_Startdatum        168 non-null    object
#  7   crm_Campagne_Status            168 non-null    object
#  8   crm_Campagne_Type_campagne     168 non-null    object
#  9   crm_Campagne_URL_voka_be       53 non-null     object
#  10  crm_Campagne_Soort_Campagne    168 non-null    object
# dtypes: object(11)
# memory usage: 14.6+ KB

# %%
data[data['crm_Campagne_URL_voka_be'].notnull()].head()
# Out:
#                    crm_Campagne_Campagne crm_Campagne_Campagne_Nr
# 1   03418937-184E-ED11-BBA2-6045BD8952CE            22-OV-01-0172  \
# 9   0BB0A1DD-67B3-ED11-83FF-6045BD8956C9            23-OV-01-0062
# 11  0F57AC8B-EFBA-EC11-983F-6045BD8C52BD            22-OV-01-0094
# 15  1314F31E-1D1A-EC11-8126-001DD8B72B62            21-OV-01-0120
# 20  196ECF03-10E4-ED11-A7C7-6045BD895FE4            23-OV-01-0093
#
#    crm_Campagne_Einddatum                                 crm_Campagne_Naam
# 1      10-2-2023 14:30:00  OV-MA/NW-Regiolunch-Zaken die smaken-Meetjesland  \
# 9      30-3-2023 21:00:00                         OV-NW-Vaart Club-30 maart
# 11      9-6-2022 09:30:00                 OV-NW-Voka Politica Maldegem 2022
# 15    21-10-2021 10:30:00      OV-Match-#WelkomBijVokaVaart-21 oktober 2021
# 20      6-7-2023 21:00:00                        OV-NW-Vaart Club-Juli 2023
#
#                            crm_Campagne_Naam_in_email
# ...
