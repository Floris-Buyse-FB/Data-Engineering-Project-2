# %%
import pandas as pd
import re

data = pd.read_csv('../data/cdi pageviews.csv', encoding="latin-1", sep=";")
data.columns = data.columns.map(lambda x: re.sub(r'^crm CDI_PageView\[(.*)\]$', r'\1', x))
data.columns = data.columns.map(lambda x: re.sub(r' ', r'_', x))
data.drop(['Anonymous_Visitor'], axis=1, inplace=True)
data.head()
# Out:
#    Browser Campaign                               Contact  Duration  \
# 0  ANDROID      NaN  71C7CDFA-379C-EB11-811E-001DD8B72B62       NaN
# 1   CHROME      NaN  2D1FD6B4-6575-ED11-81AB-6045BD895CDC       NaN
# 2   CHROME      NaN  2D1FD6B4-6575-ED11-81AB-6045BD895CDC       3.0
# 3   CHROME      NaN  2D1FD6B4-6575-ED11-81AB-6045BD895CDC       1.0
# 4   CHROME      NaN  2D1FD6B4-6575-ED11-81AB-6045BD895CDC       NaN
#
#   Operating_System                             Page_View   Referrer_Type  \
# 0            LINUX  44941A79-0980-461D-AEB7-20B9E49BBC73   Search Engine
# 1          WINDOWS  66BDB58C-045A-4916-960D-2B30EF276FF7           Email
# 2          WINDOWS  E7E1CCC4-20E6-4765-B99C-1E7CCA321B79           Email
# 3          WINDOWS  D3F9C81A-D70F-4F91-8141-0A9617DA433B  Direct Traffic
# 4          WINDOWS  AEA3FE35-46EE-4285-A4A4-37CECFEFDC49           Email
#
#                         Time  \
# 0  09-28-2023 16:41:02 (UTC)
# 1  09-28-2023 16:28:37 (UTC)
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Browser           499829 non-null  object
#  1   Campaign          23359 non-null   object
#  2   Contact           500000 non-null  object
#  3   Duration          354111 non-null  float64
#  4   Operating_System  500000 non-null  object
#  5   Page_View         500000 non-null  object
#  6   Referrer_Type     500000 non-null  object
#  7   Time              500000 non-null  object
#  8   Page_Title        494290 non-null  object
#  9   Type              500000 non-null  object
#  10  Url               500000 non-null  object
#  11  Viewed_On         500000 non-null  object
#  12  Visit             499895 non-null  object
#  13  Visitor_Key       500000 non-null  object
#  14  Web_Content       6195 non-null    object
#  15  Aangemaakt_op     500000 non-null  object
# ...

# %%
data.Browser.value_counts()
# Out:
# Browser
# CHROME     453320
# ANDROID     46509
# Name: count, dtype: int64

# %%
data[data['Campaign'].notnull()].head()
# Out:
#     Browser                              Campaign  \
# 9   ANDROID  6D4E5B9F-B015-EE11-8F6D-6045BD895805
# 14  ANDROID  C86B6D61-547C-ED11-81AD-6045BD895BFB
# 15  ANDROID  C86B6D61-547C-ED11-81AD-6045BD895BFB
# 16  ANDROID  C86B6D61-547C-ED11-81AD-6045BD895BFB
# 17  ANDROID  C86B6D61-547C-ED11-81AD-6045BD895BFB
#
#                                  Contact  Duration Operating_System  \
# 9   BFE04B33-8A8C-E611-80E3-001DD8B72B62       NaN            LINUX
# 14  71C7CDFA-379C-EB11-811E-001DD8B72B62       NaN            LINUX
# 15  71C7CDFA-379C-EB11-811E-001DD8B72B62       8.0            LINUX
# 16  71C7CDFA-379C-EB11-811E-001DD8B72B62       4.0            LINUX
# 17  71C7CDFA-379C-EB11-811E-001DD8B72B62      14.0            LINUX
#
#                                Page_View   Referrer_Type  \
# 9   52C979BA-E5DD-4B12-8E2A-076446BD9619           Email
# 14  D97A380E-831E-4DC7-BE0E-938BA3B5F427  Direct Traffic
# 15  5130D153-F891-4E97-8E6F-C19B828FDE23  Direct Traffic
# ...

# %%
data[data['Duration'].notnull()].head()
# Out:
#    Browser Campaign                               Contact  Duration  \
# 2   CHROME      NaN  2D1FD6B4-6575-ED11-81AB-6045BD895CDC       3.0
# 3   CHROME      NaN  2D1FD6B4-6575-ED11-81AB-6045BD895CDC       1.0
# 7   CHROME      NaN  0FE98D15-B472-E111-B43A-00505680000A      62.0
# 8   CHROME      NaN  0FE98D15-B472-E111-B43A-00505680000A       5.0
# 10  CHROME      NaN  6A36B4F0-AC1D-EB11-8117-001DD8B72B62      37.0
#
#    Operating_System                             Page_View   Referrer_Type  \
# 2           WINDOWS  E7E1CCC4-20E6-4765-B99C-1E7CCA321B79           Email
# 3           WINDOWS  D3F9C81A-D70F-4F91-8141-0A9617DA433B  Direct Traffic
# 7           WINDOWS  048EF66D-734F-4D2C-8859-F6A07CF29CFA   Search Engine
# 8           WINDOWS  AF26E741-0D0F-446B-ACCF-7B40DC1F498E   Search Engine
# 10          WINDOWS  5A6B5656-BDB5-4A72-A732-02C028EF97E9           Email
#
#                          Time  \
# 2   09-28-2023 16:28:34 (UTC)
# 3   09-28-2023 16:28:33 (UTC)
# ...

# %%
data[data['Page_Title'].notnull()].head()
# Out:
#    Browser Campaign                               Contact  Duration  \
# 0  ANDROID      NaN  71C7CDFA-379C-EB11-811E-001DD8B72B62       NaN
# 1   CHROME      NaN  2D1FD6B4-6575-ED11-81AB-6045BD895CDC       NaN
# 2   CHROME      NaN  2D1FD6B4-6575-ED11-81AB-6045BD895CDC       3.0
# 3   CHROME      NaN  2D1FD6B4-6575-ED11-81AB-6045BD895CDC       1.0
# 4   CHROME      NaN  2D1FD6B4-6575-ED11-81AB-6045BD895CDC       NaN
#
#   Operating_System                             Page_View   Referrer_Type  \
# 0            LINUX  44941A79-0980-461D-AEB7-20B9E49BBC73   Search Engine
# 1          WINDOWS  66BDB58C-045A-4916-960D-2B30EF276FF7           Email
# 2          WINDOWS  E7E1CCC4-20E6-4765-B99C-1E7CCA321B79           Email
# 3          WINDOWS  D3F9C81A-D70F-4F91-8141-0A9617DA433B  Direct Traffic
# 4          WINDOWS  AEA3FE35-46EE-4285-A4A4-37CECFEFDC49           Email
#
#                         Time  \
# 0  09-28-2023 16:41:02 (UTC)
# 1  09-28-2023 16:28:37 (UTC)
# ...

# %%
data[data['Visit'].notnull()].head()
# Out:
#    Browser Campaign                               Contact  Duration  \
# 0  ANDROID      NaN  71C7CDFA-379C-EB11-811E-001DD8B72B62       NaN
# 1   CHROME      NaN  2D1FD6B4-6575-ED11-81AB-6045BD895CDC       NaN
# 2   CHROME      NaN  2D1FD6B4-6575-ED11-81AB-6045BD895CDC       3.0
# 3   CHROME      NaN  2D1FD6B4-6575-ED11-81AB-6045BD895CDC       1.0
# 4   CHROME      NaN  2D1FD6B4-6575-ED11-81AB-6045BD895CDC       NaN
#
#   Operating_System                             Page_View   Referrer_Type  \
# 0            LINUX  44941A79-0980-461D-AEB7-20B9E49BBC73   Search Engine
# 1          WINDOWS  66BDB58C-045A-4916-960D-2B30EF276FF7           Email
# 2          WINDOWS  E7E1CCC4-20E6-4765-B99C-1E7CCA321B79           Email
# 3          WINDOWS  D3F9C81A-D70F-4F91-8141-0A9617DA433B  Direct Traffic
# 4          WINDOWS  AEA3FE35-46EE-4285-A4A4-37CECFEFDC49           Email
#
#                         Time  \
# 0  09-28-2023 16:41:02 (UTC)
# 1  09-28-2023 16:28:37 (UTC)
# ...

# %%
data[data['Web_Content'].notnull()].head()
# Out:
#     Browser Campaign                               Contact  Duration  \
# 22   CHROME      NaN  31D71351-D1A8-EB11-811B-001DD8B72B61       NaN
# 24   CHROME      NaN  31D71351-D1A8-EB11-811B-001DD8B72B61       NaN
# 25   CHROME      NaN  31D71351-D1A8-EB11-811B-001DD8B72B61       NaN
# 116  CHROME      NaN  22F5B97E-7819-EE11-8F6D-6045BD895420       NaN
# 118  CHROME      NaN  79AF11BE-216B-E111-B43A-00505680000A       NaN
#
#     Operating_System                             Page_View   Referrer_Type  \
# 22           WINDOWS  3B9A5F37-F133-4973-9D80-D4900F342534           Email
# 24           WINDOWS  2FB91E92-5EBB-4470-A6CA-21AFD9593F5B           Email
# 25           WINDOWS  7DAB2157-2475-48C9-8E6C-870AFB6085E8           Email
# 116          WINDOWS  6CBD19E8-8FE2-4624-8234-C9928D1D9221  Direct Traffic
# 118          WINDOWS  3A321C15-1EA8-4F2F-9A89-7ABD3A2206A4           Email
#
#                           Time Page_Title    Type  \
# ...

# %%
print(data.Status.unique())
print(data.Reden_van_status.unique())
print(data.Operating_System.unique())
# Out:
# ['Actief']
# ['Actief']
# ['LINUX' 'WINDOWS' 'MAC' 'MOBILE']
