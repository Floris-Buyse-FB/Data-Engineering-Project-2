# %% [markdown]
# # epic 4(sh)
#
# Als een key user kan ik voor een contact met weinig transacties een lookalike met veel transacties identificeren. Ik kan ook een clustering maken van contactpersonen die qua jobinhoud, type bedrijf, voorkeuren en (verwacht) gedrag

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('../data_clean/Account_fixed.csv') 
df.head()
# Out:
#                      account_account_id account_adres_geografische_regio  \
# 0  00002561-6762-EC11-8F8F-000D3A2E7738                  Mechelen-Kempen
# 1  00002DAC-0A69-E111-B43A-00505680000A                  Oost-Vlaanderen
# 2  00002F96-DC68-E111-B43A-00505680000A                          Limburg
# 3  00005967-2959-E411-8F25-005056B06EB4                   Vlaams-Brabant
# 4  00006DCD-DF68-E111-B43A-00505680000A                  West-Vlaanderen
#
#   account_adres_geografische_subregio account_adres_plaats  \
# 0                         Kempen-West            Herentals
# 1                          Oudenaarde               BEVERE
# 2                        Oost Limburg              KINROOI
# 3                     Regio West Side                HALLE
# 4                     Roeselare/Tielt              EMELGEM
#
#   account_adres_postcode account_adres_provincie account_industriezone_naam_  \
# 0                   2200               Antwerpen                     unknown
# ...

# %%
df = pd.read_csv('../data_clean/merged_total_no_keyphrases.csv')
df.head()
# Out:
#    financieledata_toegevoegde_waarde  financieledata_boekjaar_range  \
# 0                          413465.00                            5.0
# 1                          494107.00                            9.0
# 2                         1687010.57                            3.0
# 3                         1687010.57                            3.0
# 4                         1687010.57                            3.0
#
#                           functie_naam         account_adres  \
# 0                           medewerker            melle gent
# 1  contact lidmaatschap bedrijfsleider  geraardsbergen aalst
# 2  contact lidmaatschap bedrijfsleider   meilegem oudenaarde
# 3  contact lidmaatschap bedrijfsleider   meilegem oudenaarde
# 4  contact lidmaatschap bedrijfsleider   meilegem oudenaarde
#
#                   account_onderneming             contact_contactpersoon_id  \
# 0  familiebedrijf, diensten, vastgoed  D9303EA2-57E5-EB11-8121-001DD8B72B61
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\HOGENT\DEP2\Data-Engineering-Project-2\scripts\test3.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/HOGENT/DEP2/Data-Engineering-Project-2/scripts/test3.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> df = df.drop(['persoon_mail_thema_duurzaamheid','persoon_mail_thema_financieel_fiscaal','persoon_mail_thema_innovatie','visit_operating_system','mailing_onderwerp','mailing_name','sentemail_kliks_clicks','visit_total_pages'])
#       <a href='vscode-notebook-cell:/c%3A/HOGENT/DEP2/Data-Engineering-Project-2/scripts/test3.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> df.head()
#
# File c:\HOGENT\DEP2\Data-Engineering-Project-2\.venv\Lib\site-packages\pandas\core\frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
# ...
