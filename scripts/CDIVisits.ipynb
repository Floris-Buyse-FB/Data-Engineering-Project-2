# %%
import pandas as pd
data = pd.read_csv('../data/CDI visits.csv', sep=",", low_memory=False)
data.drop('crm_CDI_Visit_Campagne_Code', axis=1, inplace=True)
data.head()
# Out:
#   crm_CDI_Visit_Adobe_Reader crm_CDI_Visit_Bounce crm_CDI_Visit_Browser  \
# 0                         Ja                   Ja               FIREFOX
# 1                         Ja                   Ja               FIREFOX
# 2                         Ja                   Ja                    IE
# 3                         Ja                   Ja                    IE
# 4                         Ja                   Ja                    IE
#
#                  crm_CDI_Visit_Campaign crm_CDI_Visit_IP_Stad  \
# 0                                   NaN          Sint-Niklaas
# 1  AC8F3785-FA30-EC11-8127-001DD8B72B62            Gentbrugge
# 2                                   NaN            Londerzeel
# 3                                   NaN            Londerzeel
# 4                                   NaN                Ternat
#
#   crm_CDI_Visit_IP_Company                 crm_CDI_Visit_Contact  \
# 0                  Telenet  C5FF968E-EBB7-E111-A45C-00505680000A
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 727426 entries, 0 to 727425
# Data columns (total 34 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   crm_CDI_Visit_Adobe_Reader           727426 non-null  object
#  1   crm_CDI_Visit_Bounce                 727426 non-null  object
#  2   crm_CDI_Visit_Browser                726501 non-null  object
#  3   crm_CDI_Visit_Campaign               319773 non-null  object
#  4   crm_CDI_Visit_IP_Stad                723627 non-null  object
#  5   crm_CDI_Visit_IP_Company             725906 non-null  object
#  6   crm_CDI_Visit_Contact                727426 non-null  object
#  7   crm_CDI_Visit_Contact_Naam_          727426 non-null  object
#  8   crm_CDI_Visit_containssocialprofile  727426 non-null  object
#  9   crm_CDI_Visit_IP_Land                723627 non-null  object
#  10  crm_CDI_Visit_Duration               726831 non-null  float64
# ...

# %%
print(data.crm_CDI_Visit_Adobe_Reader.unique())
print(data.crm_CDI_Visit_Bounce.unique())
print(data.crm_CDI_Visit_containssocialprofile.unique())
print(data.crm_CDI_Visit_Referrer_Type.unique())
print(data.crm_CDI_Visit_IP_Status.unique())
# Out:
# ['Ja' 'Nee']
# ['Ja' 'Nee']
# ['Nee' 'Ja']
# ['Zoekmachine' 'E-mail' 'Direct verkeer' 'Onbekend' 'Sociaal']
# ['VLG' 'BRU' 'WAL' 'NH' nan 'CT' 'NOR' 'AN' 'WC' 'NW' 'GE' 'AB' 'ARA' 'CM'
#  'ZH' '14' 'MD' 'IB' 'VC' 'FL' 'UT' '5' '25' 'CL' 'VA' 'I' 'IDF' '01' 'BC'
#  'VE' '84' 'JB' '10' '02' 'RP' 'BE' '52' 'BW' 'NAQ' 'MA' 'NB' 'QLD' 'B'
#  'ZE' 'C' 'HDF' 'M' 'NC' 'BFC' 'CJ' 'ENG' 'CN' 'HE' 'DL' 'TN' 'DU' 'L'
#  'GES' '31' '15' 'PAC' '03' 'HR' 'RI' 'IS' '7' '34' '35' 'BD' '2' 'O' 'NE'
#  'PV' 'E' '11' 'LU' 'LI' 'MC' '32' 'OCC' '06' 'VS' 'CA' 'MH' 'BY' 'MI'
#  'NY' 'OV' 'PM' '72' 'PDL' '08' '30' 'PW' 'YUC' '62' 'MN' 'SP' '8' '82'
#  '04' 'BRE' 'TA' '13' '9' 'DC' '21' 'AR' 'ND' 'SB' 'NO' 'PR' 'AM' 'NJ'
#  'NI' 'GR' 'SG' 'NV' '36' 'DK' 'SCT' 'RIX' '18' 'VD' '48' 'ROO' 'GU' 'Z'
#  'ES' 'SN' '07' 'AA' 'TI' 'GP' '75' 'H' '108' 'OK' 'CO' 'DR' 'GA' 'ATY'
#  'ZG' '63' 'BS' 'TX' '00' 'KA' '24' 'ME' 'BL' 'BU' '42' 'SJ' 'SC' 'FR'
# ...

# %%
data.replace({'crm_CDI_Visit_Adobe_Reader': {'Ja': 1, 'Nee': 0}}, inplace=True)
data.replace({'crm_CDI_Visit_Bounce': {'Ja': 1, 'Nee': 0}}, inplace=True)
data.replace({'crm_CDI_Visit_containssocialprofile': {'Ja': 1, 'Nee': 0}}, inplace=True)
data.head()
# Out:
#    crm_CDI_Visit_Adobe_Reader  crm_CDI_Visit_Bounce crm_CDI_Visit_Browser  \
# 0                           1                     1               FIREFOX
# 1                           1                     1               FIREFOX
# 2                           1                     1                    IE
# 3                           1                     1                    IE
# 4                           1                     1                    IE
#
#                  crm_CDI_Visit_Campaign crm_CDI_Visit_IP_Stad  \
# 0                                   NaN          Sint-Niklaas
# 1  AC8F3785-FA30-EC11-8127-001DD8B72B62            Gentbrugge
# 2                                   NaN            Londerzeel
# 3                                   NaN            Londerzeel
# 4                                   NaN                Ternat
#
#   crm_CDI_Visit_IP_Company                 crm_CDI_Visit_Contact  \
# 0                  Telenet  C5FF968E-EBB7-E111-A45C-00505680000A
# ...

# %%
import pandas as pd
data_clean = pd.read_csv('../data_clean/CDI visits_fixed.csv', sep=",", dtype=str)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\maxit\Documents\HOGent\3e Jaar\Data Engineering Project II\Data-Engineering-Project-2\scripts\CDIVisits.ipynb Cell 4 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/maxit/Documents/HOGent/3e%20Jaar/Data%20Engineering%20Project%20II/Data-Engineering-Project-2/scripts/CDIVisits.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
# ----> <a href='vscode-notebook-cell:/c%3A/Users/maxit/Documents/HOGent/3e%20Jaar/Data%20Engineering%20Project%20II/Data-Engineering-Project-2/scripts/CDIVisits.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> data_clean = pd.read_csv('../data_clean/CDI visits_fixed.csv', sep=",", dtype=str)
#
# ...

# %%
data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 727426 entries, 0 to 727425
# Data columns (total 34 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   CDI_Visit_Adobe_Reader           727426 non-null  object
#  1   CDI_Visit_Bounce                 727426 non-null  object
#  2   CDI_Visit_Browser                726501 non-null  object
#  3   CDI_Visit_Campaign               319773 non-null  object
#  4   CDI_Visit_IP_Stad                723627 non-null  object
#  5   CDI_Visit_IP_Company             725906 non-null  object
#  6   CDI_Visit_Contact                727426 non-null  object
#  7   CDI_Visit_Contact_Naam_          727426 non-null  object
#  8   CDI_Visit_containssocialprofile  727426 non-null  object
#  9   CDI_Visit_IP_Land                723627 non-null  object
#  10  CDI_Visit_Duration               726831 non-null  object
# ...

# %%
data_clean['CDI_Visit_Campaign'].dtype
# Out:
# dtype('O')

# %%
data_clean['CDI_Visit_Keywords'].dtype
# Out:
# dtype('O')

# %%
data_clean.head()
# Out:
#   CDI_Visit_Adobe_Reader CDI_Visit_Bounce CDI_Visit_Browser
# 0                     Ja               Ja           FIREFOX  \
# 1                     Ja               Ja           FIREFOX
# 2                     Ja               Ja                IE
# 3                     Ja               Ja                IE
# 4                     Ja               Ja                IE
#
#                      CDI_Visit_Campaign CDI_Visit_IP_Stad
# 0                                   NaN      Sint-Niklaas  \
# 1  AC8F3785-FA30-EC11-8127-001DD8B72B62        Gentbrugge
# 2                                   NaN        Londerzeel
# 3                                   NaN        Londerzeel
# 4                                   NaN            Ternat
#
#   CDI_Visit_IP_Company                     CDI_Visit_Contact
# 0              Telenet  C5FF968E-EBB7-E111-A45C-00505680000A  \
# 1          Belgacom SA  7DCF89E7-D469-E111-B43A-00505680000A
# 2              Telenet  ADE0859B-B7E6-E911-8106-001DD8B72B61
# ...
